# %% [markdown]
# # Notebook – Operador Ternário em Python

# %% [markdown]
# ## Introdução
#
# O operador ternário é uma forma simplificada de escrever estruturas condicionais em Python.
#
# ### Sintaxe
#
# ```python
# valor_se_verdadeiro if condição else valor_se_falso
# ```

# %%
idade = 20

resultado = "Maior de idade" if idade >= 18 else "Menor de idade"

print(resultado)

# %% [markdown]
# # Exercício 1 – Número Par ou Ímpar
#
# Faça um programa que receba um número e informe se ele é par ou ímpar utilizando operador ternário.

# %%
n=float(int(input("Digite um número ")))
resultado = "Par" if n % 2 == 0 else "Impar"
print(resultado)
# Out:
# Par

# %% [markdown]
# # Exercício 2 – Maior ou Menor de Idade
#
# Peça a idade do usuário e informe:
# - “Maior de idade”
# - “Menor de idade”
#
# Utilize operador ternário.

# %%
id=int(input("Digite sua idade"))
resultado = "Maior de idade" if id >=18 else "Menor de idade"
print(resultado)
# Out:
# Maior de idade

# %% [markdown]
# # Exercício 3 – Maior Número
#
# Receba dois números e mostre qual deles é o maior utilizando operador ternário.

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
resultado = (f'O número {n1} é maior que {n2}') if n1 >n2 else (f'O número {n2} é maior que {n1}')
print(resultado)
# Out:
# O número 6.0 é maior que 4.0

# %% [markdown]
# # Exercício 4 – Situação do Aluno
#
# Peça a nota de um aluno e informe:
# - “Aprovado” se nota ≥ 6
# - “Reprovado” caso contrário
#
# Utilize operador ternário.

# %%
nota = float(input("Digite a nota: "))
resultado = "Aprovado" if n <=6 else "Reprovado"
print(resultado)
# Out:
# Reprovado

# %% [markdown]
# # Exercício 5 – Verificação de Senha
#
# Faça um programa que receba uma senha.
#
# Se a senha for igual a "python123", exiba:
# - “Acesso permitido”
#
# Caso contrário:
# - “Acesso negado”
#
# Utilize operador ternário.

# %%
senha = int(input("Digite sua senha" ))
resultado = "Acesso permitido" if senha == ("python123") else "Acesso Negado"
print(resultado)
# Out:
# Acesso Negado

# %% [markdown]
# # Exercício 6 – Temperatura
#
# Receba a temperatura de uma cidade.
#
# Exiba:
# - “Quente” se temperatura ≥ 30
# - “Agradável” caso contrário
#
# Utilize operador ternário.

# %%
t= int(input("Digite a temperatura atual "))
resultado1= "Quente" if t >= 30 else "Agradável"
print (resultado1)
# Out:
# Quente

# %% [markdown]
# # Exercício 7 – Número Positivo ou Negativo
#
# Faça um programa que receba um número e informe:
# - “Positivo”
# - “Negativo”
#
# Utilizando operador ternário.

# %%
x = int(input("Digite um número"))
pn = "Positivo" if x >=0 else "Negativo"
print(pn)
# Out:
# Negativo

# %% [markdown]
# # Exercício 8 – Desconto em Compras
#
# Peça o valor de uma compra.
#
# Se o valor for maior ou igual a R$100, aplique 10% de desconto.
# Caso contrário, mantenha o valor original.

# %%
n= float(int((input("Digite o valor da compra "))))
resultad8 = n - (10/100*n) if n >=100 else n 
print(resultad8)
# Out:
# 180.0

# %% [markdown]
# # Exercício 9 – Login Simples
#
# Peça o nome do usuário.
#
# Se o nome for “admin”, exiba:
# - “Administrador”
#
# Caso contrário:
# - “Usuário comum”

# %%
usuario = input("Digite usuário")
nome = "Administrador" if usuario=="admin" else "Usuário comum"
print(nome)
# Out:
# Administrador

# %% [markdown]
# # Exercício 10 – Média do Aluno
#
# Receba duas notas.
#
# Calcule a média e informe:
# - “Aprovado” se média ≥ 6
# - “Recuperação” se média entre 4 e 5.9
# - “Reprovado” se média < 4

# %%
nota1= float(input("Digite nota 1:"))
nota2= float(input("Digite nota 2:"))
media= (nota1+nota2)/2
result10= "Aprovado" if media >=6 else "Recuperação" if media >=4 else "Reprovado"
print(result10)
# Out:
# Aprovado

# %% [markdown]
# # Resumo Final
#
# ## Estrutura do Operador Ternário
#
# ```python
# valor_if if condição else valor_else
# ```
#
# ### Vantagens
# - Código mais curto
# - Melhor legibilidade
# - Muito utilizado em Python
